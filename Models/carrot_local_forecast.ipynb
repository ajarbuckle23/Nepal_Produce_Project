# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error

color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
def create_features(df):
    
    # This function creates time series features based on the date of recording
    
    df = df.copy()
    
    df['DayofWeek']= df.index.dayofweek
    df['Month'] = df.index.month
    df['Year'] = df.index.year
    df['DayofYear'] = df.index.dayofyear
    
    return df

# %%
produce_data = pd.read_csv('/Users/ajarbuckle/Desktop/Produce Project/Original Data/produce_price_timeseries.csv')

# Getting rid of unnecessary columns 
produce_data = produce_data[['Commodity', 'Date', 'Average']]

# Changing some column names 
produce_data.rename(columns={'Average': 'Price', 'Commodity': 'Item'}, inplace=True)

produce_data
# Out:
#                        Item        Date  Price
# 0        Tomato Big(Nepali)  2013-06-16   37.5
# 1       Tomato Small(Local)  2013-06-16   29.0
# 2                Potato Red  2013-06-16   20.5
# 3              Potato White  2013-06-16   15.5
# 4        Onion Dry (Indian)  2013-06-16   29.0
# ...                     ...         ...    ...
# 197156    Garlic Dry Nepali  2021-05-13  110.0
# 197157     Fish Fresh(Rahu)  2021-05-13  275.0
# 197158  Fish Fresh(Bachuwa)  2021-05-13  230.0
# 197159   Fish Fresh(Chhadi)  2021-05-13  225.0
# 197160  Fish Fresh(Mungari)  2021-05-13  245.0
#
# [197161 rows x 3 columns]

# %%
# Making sure that the 'Date' column is a date variable

produce_data['Date'] = pd.to_datetime(produce_data['Date'])
produce_data.dtypes
# Out:
# Item             object
# Date     datetime64[ns]
# Price           float64
# dtype: object

# %%
# Setting the 'Date' column to be the index of the dataframe; this is necessary for time series analyses

produce_data.set_index('Date', inplace=True)
produce_data
# Out:
#                            Item  Price
# Date
# 2013-06-16   Tomato Big(Nepali)   37.5
# 2013-06-16  Tomato Small(Local)   29.0
# 2013-06-16           Potato Red   20.5
# 2013-06-16         Potato White   15.5
# 2013-06-16   Onion Dry (Indian)   29.0
# ...                         ...    ...
# 2021-05-13    Garlic Dry Nepali  110.0
# 2021-05-13     Fish Fresh(Rahu)  275.0
# 2021-05-13  Fish Fresh(Bachuwa)  230.0
# 2021-05-13   Fish Fresh(Chhadi)  225.0
# 2021-05-13  Fish Fresh(Mungari)  245.0
#
# [197161 rows x 2 columns]

# %%
# Splitting the dataframe up by item 

carrot = produce_data[produce_data['Item'] == 'Carrot(Local)']
carrot
# Out:
#                      Item  Price
# Date
# 2013-06-16  Carrot(Local)   32.5
# 2013-06-17  Carrot(Local)   37.5
# 2013-06-18  Carrot(Local)   37.5
# 2013-06-19  Carrot(Local)   40.0
# 2013-06-20  Carrot(Local)   41.0
# ...                   ...    ...
# 2021-05-09  Carrot(Local)   55.0
# 2021-05-10  Carrot(Local)   45.0
# 2021-05-11  Carrot(Local)   45.0
# 2021-05-12  Carrot(Local)   47.5
# 2021-05-13  Carrot(Local)   55.0
#
# [2736 rows x 2 columns]

# %%
# Visualizing the time series data

carrot.plot(style = '.', figsize = (15,5), color = color_pal[0], title = 'Carrot Local Prices Over Time', legend = False)
# Out:
# <AxesSubplot:title={'center':'Carrot Local Prices Over Time'}, xlabel='Date'>

# %%
# Creating training and test sets; training set will be all data before 2020, test set wil be all data after 2020
train = carrot.loc[carrot.index <= '2019-12-31']
test = carrot.loc[carrot.index > '2019-12-31']

# Visualizing
fig, ax = plt.subplots(figsize = (15,5))
train.plot(ax = ax, label = 'Training Set')
test.plot(ax = ax, label = 'Test Set')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
# Adding in the time series features to the original dataframe (before splitting into training and test sets) 
# to make sure that it's working properly 

carrot = create_features(carrot)
carrot
# Out:
#                      Item  Price  DayofWeek  Month  Year  DayofYear
# Date
# 2013-06-16  Carrot(Local)   32.5          6      6  2013        167
# 2013-06-17  Carrot(Local)   37.5          0      6  2013        168
# 2013-06-18  Carrot(Local)   37.5          1      6  2013        169
# 2013-06-19  Carrot(Local)   40.0          2      6  2013        170
# 2013-06-20  Carrot(Local)   41.0          3      6  2013        171
# ...                   ...    ...        ...    ...   ...        ...
# 2021-05-09  Carrot(Local)   55.0          6      5  2021        129
# 2021-05-10  Carrot(Local)   45.0          0      5  2021        130
# 2021-05-11  Carrot(Local)   45.0          1      5  2021        131
# 2021-05-12  Carrot(Local)   47.5          2      5  2021        132
# 2021-05-13  Carrot(Local)   55.0          3      5  2021        133
#
# [2736 rows x 6 columns]

# %%
# Creating boxplots of prices per month

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=carrot, x='Month', y='Price')
ax.set_title('Prices by Month')
plt.show()

# %%
# Creating the time series features in the training and test sets 

train = create_features(train)
test = create_features(test)

# %%
# Labeling out feature and target variables

FEATURES = ['DayofWeek', 'Month', 'Year', 'DayofYear']
TARGET = 'Price'

# %%
x_train = train[FEATURES]
y_train = train[TARGET]

x_test = test[FEATURES]
y_test = test[TARGET]

# %%
# Creating the model 

reg = xgb.XGBRegressor(n_estimators = 1000, early_stopping_rounds = 50, learning_rate = 0.01)
reg.fit(x_train, y_train,
        eval_set = [(x_train, y_train), (x_test, y_test)],
        verbose = 100)
# Out:
# [0]	validation_0-rmse:32.44264	validation_1-rmse:26.66114
# [88]	validation_0-rmse:16.31250	validation_1-rmse:25.79788
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Feature importance 

fi = pd.DataFrame(data = reg.feature_importances_,
             index = reg.feature_names_in_,
             columns = ['importance'])
fi.sort_values(by = 'importance', ascending = False)
# Out:
#            importance
# DayofYear    0.509140
# Month        0.296585
# Year         0.191234
# DayofWeek    0.003041

# %%
fi.sort_values('importance').plot(kind = 'barh', title = 'Feature Importance')
# Out:
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
# Creating a new column in the test dataframe that stores the value that our model predicted for each date

test['prediction'] = reg.predict(x_test)
test
# Out:
#                      Item  Price  DayofWeek  Month  Year  DayofYear  \
# Date
# 2020-01-01  Carrot(Local)   67.5          2      1  2020          1
# 2020-01-02  Carrot(Local)   62.5          3      1  2020          2
# 2020-01-03  Carrot(Local)   67.5          4      1  2020          3
# 2020-01-04  Carrot(Local)   62.5          5      1  2020          4
# 2020-01-05  Carrot(Local)   62.5          6      1  2020          5
# ...                   ...    ...        ...    ...   ...        ...
# 2021-05-09  Carrot(Local)   55.0          6      5  2021        129
# 2021-05-10  Carrot(Local)   45.0          0      5  2021        130
# 2021-05-11  Carrot(Local)   45.0          1      5  2021        131
# 2021-05-12  Carrot(Local)   47.5          2      5  2021        132
# 2021-05-13  Carrot(Local)   55.0          3      5  2021        133
#
#             prediction
# Date
# 2020-01-01   60.340607
# 2020-01-02   60.340607
# 2020-01-03   60.340607
# 2020-01-04   60.340607
# 2020-01-05   60.340607
# ...                ...
# 2021-05-09   52.108200
# 2021-05-10   52.108200
# 2021-05-11   52.108200
# 2021-05-12   59.018162
# 2021-05-13   59.018162
#
# [485 rows x 7 columns]

# %%
# Taking the predicted values and merging them into the original dataframe so we can see the predicted values and the 
# actual values side by side 

carrot = carrot.merge(test[['prediction']], how = 'left', left_index = True, right_index = True)
carrot
# Out:
#                      Item  Price  DayofWeek  Month  Year  DayofYear  \
# Date
# 2013-06-16  Carrot(Local)   32.5          6      6  2013        167
# 2013-06-17  Carrot(Local)   37.5          0      6  2013        168
# 2013-06-18  Carrot(Local)   37.5          1      6  2013        169
# 2013-06-19  Carrot(Local)   40.0          2      6  2013        170
# 2013-06-20  Carrot(Local)   41.0          3      6  2013        171
# ...                   ...    ...        ...    ...   ...        ...
# 2021-05-09  Carrot(Local)   55.0          6      5  2021        129
# 2021-05-10  Carrot(Local)   45.0          0      5  2021        130
# 2021-05-11  Carrot(Local)   45.0          1      5  2021        131
# 2021-05-12  Carrot(Local)   47.5          2      5  2021        132
# 2021-05-13  Carrot(Local)   55.0          3      5  2021        133
#
#             prediction
# Date
# 2013-06-16         NaN
# 2013-06-17         NaN
# 2013-06-18         NaN
# 2013-06-19         NaN
# 2013-06-20         NaN
# ...                ...
# 2021-05-09   52.108200
# 2021-05-10   52.108200
# 2021-05-11   52.108200
# 2021-05-12   59.018162
# 2021-05-13   59.018162
#
# [2736 rows x 7 columns]

# %%
# Visualizing the predicted values on top of the actual values 

ax = carrot[['Price']].plot(figsize = (15, 5))
carrot['prediction'].plot(ax = ax, style = '.')
plt.legend(['Actual Data', 'Predictions'])
ax.set_title('Raw Data and Predictions')
plt.show()

# %%
# Visualizing the predicted values on top of the actual values for the year of 2020 only 

ax = carrot.loc[carrot.index > '2019-12-31']['Price'] \
    .plot(figsize=(15, 5), title='Post-2019 Data')
carrot.loc[carrot.index > '2019-12-31']['prediction'] \
    .plot(style='.')
plt.legend(['Actual Data', 'Predictions'])
ax.set_title('Raw Data and Predictions: Post-2019')
plt.show()

# %%
# Calculating accuracy of model (root mean squared error; same metric used to evaluate model as it trained

eval_score = np.sqrt(mean_squared_error(test[TARGET], test['prediction']))
print(f'RMSE Score on Test set: {eval_score:0.2f}')
# Out:
# RMSE Score on Test set: 24.03

# %%
# Calculating error of model as a new column on our test dataframe 

test['error'] = np.abs(test[TARGET] - test['prediction'])
test
# Out:
#                      Item  Price  DayofWeek  Month  Year  DayofYear  \
# Date
# 2020-01-01  Carrot(Local)   67.5          2      1  2020          1
# 2020-01-02  Carrot(Local)   62.5          3      1  2020          2
# 2020-01-03  Carrot(Local)   67.5          4      1  2020          3
# 2020-01-04  Carrot(Local)   62.5          5      1  2020          4
# 2020-01-05  Carrot(Local)   62.5          6      1  2020          5
# ...                   ...    ...        ...    ...   ...        ...
# 2021-05-09  Carrot(Local)   55.0          6      5  2021        129
# 2021-05-10  Carrot(Local)   45.0          0      5  2021        130
# 2021-05-11  Carrot(Local)   45.0          1      5  2021        131
# 2021-05-12  Carrot(Local)   47.5          2      5  2021        132
# 2021-05-13  Carrot(Local)   55.0          3      5  2021        133
#
#             prediction      error
# Date
# 2020-01-01   60.340607   7.159393
# 2020-01-02   60.340607   2.159393
# 2020-01-03   60.340607   7.159393
# 2020-01-04   60.340607   2.159393
# 2020-01-05   60.340607   2.159393
# ...                ...        ...
# 2021-05-09   52.108200   2.891800
# 2021-05-10   52.108200   7.108200
# 2021-05-11   52.108200   7.108200
# 2021-05-12   59.018162  11.518162
# 2021-05-13   59.018162   4.018162
#
# [485 rows x 8 columns]

# %%
# Seeing which months our model predicts the best for 

test.groupby('Month')['error'].mean().sort_values()
# Out:
# Month
# 3     11.321636
# 2     11.630148
# 11    11.810959
# 12    16.043572
# 1     18.124555
# 8     19.307020
# 7     19.562036
# 4     20.372390
# 5     23.607780
# 9     32.232849
# 6     32.653360
# 10    34.997054
# Name: error, dtype: float64

# %%
# Evaluating the model against a comparison model: predictions that are just the average for each month from the training set

# Creating a new dataframe that holds this information

# Getting just the month and price columns from the training set dataframe
monthly_averages = train[['Month', 'Price']]
monthly_averages = monthly_averages.reset_index(drop=True)

# Calculating the average price for each month 
monthly_averages = monthly_averages.groupby('Month')['Price'].mean().reset_index()
monthly_averages
# Out:
#     Month       Price
# 0       1   41.040230
# 1       2   26.896226
# 2       3   25.727545
# 3       4   36.488304
# 4       5   43.247159
# 5       6   61.526882
# 6       7   82.860190
# 7       8   81.539216
# 8       9   93.272500
# 9      10  100.666667
# 10     11   94.320197
# 11     12   61.420792

# %%
# Merging monthly average information into the test dataframe to be able to calculate the comparison model's errors

# Renaming 'Price' column in monthly_averages dataframe to 'CompPrediction' so that the original Price column name isn't changed 
monthly_averages.rename(columns = {'Price': 'CompPrediction'}, inplace = True)

test = test.merge(monthly_averages, on='Month', how='left')
test
# Out:
#               Item  Price  DayofWeek  Month  Year  DayofYear  prediction  \
# 0    Carrot(Local)   67.5          2      1  2020          1   60.340607
# 1    Carrot(Local)   62.5          3      1  2020          2   60.340607
# 2    Carrot(Local)   67.5          4      1  2020          3   60.340607
# 3    Carrot(Local)   62.5          5      1  2020          4   60.340607
# 4    Carrot(Local)   62.5          6      1  2020          5   60.340607
# ..             ...    ...        ...    ...   ...        ...         ...
# 480  Carrot(Local)   55.0          6      5  2021        129   52.108200
# 481  Carrot(Local)   45.0          0      5  2021        130   52.108200
# 482  Carrot(Local)   45.0          1      5  2021        131   52.108200
# 483  Carrot(Local)   47.5          2      5  2021        132   59.018162
# 484  Carrot(Local)   55.0          3      5  2021        133   59.018162
#
#          error  CompPrediction
# 0     7.159393       41.040230
# 1     2.159393       41.040230
# 2     7.159393       41.040230
# 3     2.159393       41.040230
# 4     2.159393       41.040230
# ..         ...             ...
# 480   2.891800       43.247159
# 481   7.108200       43.247159
# 482   7.108200       43.247159
# 483  11.518162       43.247159
# 484   4.018162       43.247159
#
# [485 rows x 9 columns]

# %%
# Calculating the comparison model's error
test['CompError'] = np.abs(test[TARGET] - test['CompPrediction'])
test
# Out:
#               Item  Price  DayofWeek  Month  Year  DayofYear  prediction  \
# 0    Carrot(Local)   67.5          2      1  2020          1   60.340607
# 1    Carrot(Local)   62.5          3      1  2020          2   60.340607
# 2    Carrot(Local)   67.5          4      1  2020          3   60.340607
# 3    Carrot(Local)   62.5          5      1  2020          4   60.340607
# 4    Carrot(Local)   62.5          6      1  2020          5   60.340607
# ..             ...    ...        ...    ...   ...        ...         ...
# 480  Carrot(Local)   55.0          6      5  2021        129   52.108200
# 481  Carrot(Local)   45.0          0      5  2021        130   52.108200
# 482  Carrot(Local)   45.0          1      5  2021        131   52.108200
# 483  Carrot(Local)   47.5          2      5  2021        132   59.018162
# 484  Carrot(Local)   55.0          3      5  2021        133   59.018162
#
#          error  CompPrediction  CompError
# 0     7.159393       41.040230  26.459770
# 1     2.159393       41.040230  21.459770
# 2     7.159393       41.040230  26.459770
# 3     2.159393       41.040230  21.459770
# 4     2.159393       41.040230  21.459770
# ..         ...             ...        ...
# 480   2.891800       43.247159  11.752841
# 481   7.108200       43.247159   1.752841
# 482   7.108200       43.247159   1.752841
# 483  11.518162       43.247159   4.252841
# 484   4.018162       43.247159  11.752841
#
# [485 rows x 10 columns]

# %%
# Calculating RMSE for the comparison model 
comp_eval_score = np.sqrt(mean_squared_error(test[TARGET], test['CompPrediction']))
print(f'RMSE Score on Test set: {comp_eval_score:0.2f}')
# Out:
# RMSE Score on Test set: 27.78

# %%
# Calculating how much more accurate our model is than the comparison model 
percentage_difference = ((comp_eval_score - eval_score) / comp_eval_score) * 100 
print(f'Our model is {percentage_difference:f}% more accurate than the comparison model')
# Out:
# Our model is 13.520052% more accurate than the comparison model
